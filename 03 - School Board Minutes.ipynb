# %% [markdown]
# # School Board Minutes
#
# Scrape all of the school board minutes from http://www.mineral.k12.nv.us/pages/School_Board_Minutes
#
# Save a CSV called `minutes.csv` with the date and the URL to the file. The date should be formatted as YYYY-MM-DD.
#
# **Bonus:** Download the PDF files
#
# **Bonus 2:** Use [PDF OCR X](https://solutions.weblite.ca/pdfocrx/index.php) on one of the PDF files and see if it can be converted into text successfully.
#
# * **Hint:** If you're just looking for links, there are a lot of other links on that page! Can you look at the link to know whether it links or minutes or not? You'll want to use an "if" statement.
# * **Hint:** You could also filter out bad links later on using pandas instead of when scraping
# * **Hint:** If you get a weird error that you can't really figure out, you can always tell Python to just ignore it using `try` and `except`, like below. Python will try to do the stuff inside of 'try', but if it hits an error it will skip right out.
# * **Hint:** Remember the codes at http://strftime.org
# * **Hint:** If you have a date that you've parsed, you can use `.dt.strftime` to turn it into a specially-formatted string. You use the same codes (like %B etc) that you use for converting strings into dates.
#
# ```python
# try:
#   blah blah your code
#   your code
#   your code
# except:
#   pass
# ```

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import numpy as np

# %%
response = requests.get("http://www.mineral.k12.nv.us/pages/School_Board_Minutes")
doc = BeautifulSoup(response.text)

# %%
tables = doc.find_all("span")
rows=[]

for table in tables:
    row = {}
    try:
        row["url"] = table.find("a")["href"]
    except:
        pass
    try:
        row["date"] = table.find("a")["href"]
    except:
        pass
    rows.append(row)
    
print(rows)
# Out:
# [{}, {}, {}, {'url': 'https://www2.ed.gov/policy/gen/guid/fpco/ferpa/index.html', 'date': 'https://www2.ed.gov/policy/gen/guid/fpco/ferpa/index.html'}, {}, {}, {'url': 'http://www.doe.nv.gov/Assessments/', 'date': 'http://www.doe.nv.gov/Assessments/'}, {}, {}, {'url': 'https://online.nvdoe.org/#/VerifyLicense', 'date': 'https://online.nvdoe.org/#/VerifyLicense'}, {}, {'url': 'http://www.ets.org/parapro', 'date': 'http://www.ets.org/parapro'}, {}, {}, {}, {'url': 'http://www.mineral.k12.nv.us/files/diploma_requesst.pdf', 'date': 'http://www.mineral.k12.nv.us/files/diploma_requesst.pdf'}, {}, {}, {'url': 'http://www.mineral.k12.nv.us/files/diploma_requesst.pdf', 'date': 'http://www.mineral.k12.nv.us/files/diploma_requesst.pdf'}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {'url': '/files/6.4.19_minutes.pdf', 'date': '/files/6.4.19_minutes.pdf'}, {}, {'url': '/files/5.28.19_minutes.pdf', 'date': '/files/5.28.19_minutes.pdf'}, {}, {'url': '/files/5.7.19_minutes.pdf', 'date': '/files/5.7.19_minutes.pdf'}, {}, {'url': '/files/4.23.19_minutes.pdf', 'date': '/files/4.23.19_minutes.pdf'}, {}, {'url': '/files/4.8.19_minutes.pdf', 'date': '/files/4.8.19_minutes.pdf'}, {}, {'url': '/files/3.5.19_minutes.pdf', 'date': '/files/3.5.19_minutes.pdf'}, {}, {'url': '/files/3.5.19.pdf', 'date': '/files/3.5.19.pdf'}, {}, {'url': '/files/2.26.19_minutes.pdf', 'date': '/files/2.26.19_minutes.pdf'}, {}, {'url': '/files/2.5.19_minutes.pdf', 'date': '/files/2.5.19_minutes.pdf'}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {'url': '/files/8.7.18_minutes.pdf', 'date': '/files/8.7.18_minutes.pdf'}, {}, {'url': '/files/7.24.18_minutes.pdf', 'date': '/files/7.24.18_minutes.pdf'}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {'url': '/files/6.19.18_minutes.pdf', 'date': '/files/6.19.18_minutes.pdf'}, {}, {}, {}, {}, {}, {}, {}, {}, {'url': '/files/4.17.18.pdf', 'date': '/files/4.17.18.pdf'}, {}, {'url': '/files/april_2,_2018_minutes.pdf', 'date': '/files/april_2,_2018_minutes.pdf'}, {}, {}, {}, {}, {}, {}, {'url': '/files/3.8.18.pdf', 'date': '/files/3.8.18.pdf'}, {}, {'url': '/files/march_6,_2018_minutes.pdf', 'date': '/files/march_6,_2018_minutes.pdf'}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {'url': '/files/1.5.17_minutes.pdf', 'date': '/files/1.5.17_minutes.pdf'}, {}, {'url': '/files/1.26.17_minutes.pdf', 'date': '/files/1.26.17_minutes.pdf'}, {}, {'url': '/files/2.2.17_minutes.pdf', 'date': '/files/2.2.17_minutes.pdf'}, {}, {'url': '/files/2.16.17_minutes.pdf', 'date': '/files/2.16.17_minutes.pdf'}, {}, {'url': '/files/3.2.17__minutes.pdf', 'date': '/files/3.2.17__minutes.pdf'}, {}, {'url': '/files/3.16.17_minutes.pdf', 'date': '/files/3.16.17_minutes.pdf'}, {}, {'url': '/files/4.12.17_minutes.pdf', 'date': '/files/4.12.17_minutes.pdf'}, {}, {'url': '/files/5.1.17_Minutes.pdf', 'date': '/files/5.1.17_Minutes.pdf'}, {}, {'url': '/files/5.4.17_minutes.pdf', 'date': '/files/5.4.17_minutes.pdf'}, {'url': '/files/5.4.17_minutes.pdf', 'date': '/files/5.4.17_minutes.pdf'}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {'url': 'http://www.mineral.k12.nv.us/pages/School_Board_Connection', 'date': 'http://www.mineral.k12.nv.us/pages/School_Board_Connection'}, {}, {'url': 'http://www.mineral.k12.nv.us/pages/School_Board_Agendas', 'date': 'http://www.mineral.k12.nv.us/pages/School_Board_Agendas'}, {}, {}, {'url': '/files/2017-_Draft_School_Board_3.pdf', 'date': '/files/2017-_Draft_School_Board_3.pdf'}, {}, {}, {}, {'url': '/files/AGENDA_ITEM_REQUEST_FORM.pdf', 'date': '/files/AGENDA_ITEM_REQUEST_FORM.pdf'}, {}, {'url': '/files/Board_Back-Up_Request_Form.pdf', 'date': '/files/Board_Back-Up_Request_Form.pdf'}, {}, {}, {}, {}, {}, {}, {}, {}, {'url': '/pages/HJHS', 'date': '/pages/HJHS'}, {}, {'url': '/pages/SES', 'date': '/pages/SES'}, {'url': '/pages/SES', 'date': '/pages/SES'}, {}, {}]

# %%
df = pd.DataFrame(rows)

# %%
df = df.dropna()

# %%
df["date"] = df[df.date.str.contains("_minutes.pdf", na = False, flags=re.IGNORECASE)]

# %%
df = df.dropna()

# %%
df
# Out:
#                                  date                               url
# 31          /files/6.4.19_minutes.pdf         /files/6.4.19_minutes.pdf
# 33         /files/5.28.19_minutes.pdf        /files/5.28.19_minutes.pdf
# 35          /files/5.7.19_minutes.pdf         /files/5.7.19_minutes.pdf
# 37         /files/4.23.19_minutes.pdf        /files/4.23.19_minutes.pdf
# 39          /files/4.8.19_minutes.pdf         /files/4.8.19_minutes.pdf
# 41          /files/3.5.19_minutes.pdf         /files/3.5.19_minutes.pdf
# 45         /files/2.26.19_minutes.pdf        /files/2.26.19_minutes.pdf
# 47          /files/2.5.19_minutes.pdf         /files/2.5.19_minutes.pdf
# 68          /files/8.7.18_minutes.pdf         /files/8.7.18_minutes.pdf
# 70         /files/7.24.18_minutes.pdf        /files/7.24.18_minutes.pdf
# 80         /files/6.19.18_minutes.pdf        /files/6.19.18_minutes.pdf
# 91   /files/april_2,_2018_minutes.pdf  /files/april_2,_2018_minutes.pdf
# 100  /files/march_6,_2018_minutes.pdf  /files/march_6,_2018_minutes.pdf
# 113         /files/1.5.17_minutes.pdf         /files/1.5.17_minutes.pdf
# 115        /files/1.26.17_minutes.pdf        /files/1.26.17_minutes.pdf
# 117         /files/2.2.17_minutes.pdf         /files/2.2.17_minutes.pdf
# 119        /files/2.16.17_minutes.pdf        /files/2.16.17_minutes.pdf
# 121        /files/3.2.17__minutes.pdf        /files/3.2.17__minutes.pdf
# 123        /files/3.16.17_minutes.pdf        /files/3.16.17_minutes.pdf
# 125        /files/4.12.17_minutes.pdf        /files/4.12.17_minutes.pdf
# 127         /files/5.1.17_Minutes.pdf         /files/5.1.17_Minutes.pdf
# 129         /files/5.4.17_minutes.pdf         /files/5.4.17_minutes.pdf
# 130         /files/5.4.17_minutes.pdf         /files/5.4.17_minutes.pdf

# %%
df["date"] = df["date"].str.replace ("/files/april_2,_2018_minutes.pdf", "/files/4.2.18_minutes.pdf")
df["date"] = df["date"].str.replace ("/files/march_6,_2018_minutes.pdf", "/files/3.6.18_minutes.pdf")

# %%
regex_pat = re.compile(r'_..*', flags=re.IGNORECASE)
df["date"] = df["date"].str.replace(regex_pat, "")

# %%
regex_pat = re.compile(r'/files/', flags=re.IGNORECASE)
df["date"] = df["date"].str.replace(regex_pat, "")

# %%
df
# Out:
#         date                               url
# 31    6.4.19         /files/6.4.19_minutes.pdf
# 33   5.28.19        /files/5.28.19_minutes.pdf
# 35    5.7.19         /files/5.7.19_minutes.pdf
# 37   4.23.19        /files/4.23.19_minutes.pdf
# 39    4.8.19         /files/4.8.19_minutes.pdf
# 41    3.5.19         /files/3.5.19_minutes.pdf
# 45   2.26.19        /files/2.26.19_minutes.pdf
# 47    2.5.19         /files/2.5.19_minutes.pdf
# 68    8.7.18         /files/8.7.18_minutes.pdf
# 70   7.24.18        /files/7.24.18_minutes.pdf
# 80   6.19.18        /files/6.19.18_minutes.pdf
# 91    4.2.18  /files/april_2,_2018_minutes.pdf
# 100   3.6.18  /files/march_6,_2018_minutes.pdf
# 113   1.5.17         /files/1.5.17_minutes.pdf
# 115  1.26.17        /files/1.26.17_minutes.pdf
# 117   2.2.17         /files/2.2.17_minutes.pdf
# 119  2.16.17        /files/2.16.17_minutes.pdf
# 121   3.2.17        /files/3.2.17__minutes.pdf
# 123  3.16.17        /files/3.16.17_minutes.pdf
# 125  4.12.17        /files/4.12.17_minutes.pdf
# 127   5.1.17         /files/5.1.17_Minutes.pdf
# 129   5.4.17         /files/5.4.17_minutes.pdf
# 130   5.4.17         /files/5.4.17_minutes.pdf

# %%
df['date'] = df['date'].apply(lambda value: f'{value[4:]}-{value[:2]}-{value[2:4]}')

# %%
df
# Out:
#           date                               url
# 31    19-6.-4.         /files/6.4.19_minutes.pdf
# 33   .19-5.-28        /files/5.28.19_minutes.pdf
# 35    19-5.-7.         /files/5.7.19_minutes.pdf
# 37   .19-4.-23        /files/4.23.19_minutes.pdf
# 39    19-4.-8.         /files/4.8.19_minutes.pdf
# 41    19-3.-5.         /files/3.5.19_minutes.pdf
# 45   .19-2.-26        /files/2.26.19_minutes.pdf
# 47    19-2.-5.         /files/2.5.19_minutes.pdf
# 68    18-8.-7.         /files/8.7.18_minutes.pdf
# 70   .18-7.-24        /files/7.24.18_minutes.pdf
# 80   .18-6.-19        /files/6.19.18_minutes.pdf
# 91    18-4.-2.  /files/april_2,_2018_minutes.pdf
# 100   18-3.-6.  /files/march_6,_2018_minutes.pdf
# 113   17-1.-5.         /files/1.5.17_minutes.pdf
# 115  .17-1.-26        /files/1.26.17_minutes.pdf
# 117   17-2.-2.         /files/2.2.17_minutes.pdf
# 119  .17-2.-16        /files/2.16.17_minutes.pdf
# 121   17-3.-2.        /files/3.2.17__minutes.pdf
# 123  .17-3.-16        /files/3.16.17_minutes.pdf
# 125  .17-4.-12        /files/4.12.17_minutes.pdf
# 127   17-5.-1.         /files/5.1.17_Minutes.pdf
# 129   17-5.-4.         /files/5.4.17_minutes.pdf
# 130   17-5.-4.         /files/5.4.17_minutes.pdf

# %%
regex_pat = re.compile(r'[.]', flags=re.IGNORECASE)
df["date"] = df["date"].str.replace(regex_pat, "")

# %%
df
# Out:
#         date                               url
# 31    19-6-4         /files/6.4.19_minutes.pdf
# 33   19-5-28        /files/5.28.19_minutes.pdf
# 35    19-5-7         /files/5.7.19_minutes.pdf
# 37   19-4-23        /files/4.23.19_minutes.pdf
# 39    19-4-8         /files/4.8.19_minutes.pdf
# 41    19-3-5         /files/3.5.19_minutes.pdf
# 45   19-2-26        /files/2.26.19_minutes.pdf
# 47    19-2-5         /files/2.5.19_minutes.pdf
# 68    18-8-7         /files/8.7.18_minutes.pdf
# 70   18-7-24        /files/7.24.18_minutes.pdf
# 80   18-6-19        /files/6.19.18_minutes.pdf
# 91    18-4-2  /files/april_2,_2018_minutes.pdf
# 100   18-3-6  /files/march_6,_2018_minutes.pdf
# 113   17-1-5         /files/1.5.17_minutes.pdf
# 115  17-1-26        /files/1.26.17_minutes.pdf
# 117   17-2-2         /files/2.2.17_minutes.pdf
# 119  17-2-16        /files/2.16.17_minutes.pdf
# 121   17-3-2        /files/3.2.17__minutes.pdf
# 123  17-3-16        /files/3.16.17_minutes.pdf
# 125  17-4-12        /files/4.12.17_minutes.pdf
# 127   17-5-1         /files/5.1.17_Minutes.pdf
# 129   17-5-4         /files/5.4.17_minutes.pdf
# 130   17-5-4         /files/5.4.17_minutes.pdf

# %%
df.to_csv("school_board", index= False)
